# %% [markdown]
# <a href="https://colab.research.google.com/github/Arjunkalliyadath/Github-Project/blob/main/Casestudy_on_numpy_and_pandas_(01_12_2025).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1) Import pandas, numpy

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 2) Load dataset using pd.read_csv()

# %%
df = pd.read_csv('https://raw.githubusercontent.com/laxmimerit/All-CSV-ML-Data-Files-Download/master/IMDB-Movie-Data.csv')
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# 3) Display: shape, head, column names, datatypes, missing value

# %%
df.shape
# Out:
# (1000, 12)

# %%
df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Rank                    int64
# Title                  object
# Genre                  object
# Description            object
# Director               object
# Actors                 object
# Year                    int64
# Runtime (Minutes)       int64
# Rating                float64
# Votes                   int64
# Revenue (Millions)    float64
# Metascore             float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %% [markdown]
#  4) Check and remove duplicates

# %%
print("Number of Duplicate Rows:", df.duplicated().sum())
df = df.drop_duplicates()
print("Shape after removing duplicates:", df.shape)
# Out:
# Number of Duplicate Rows: 0
# Shape after removing duplicates: (1000, 16)

# %% [markdown]
#  5) Rename columns ("Title" > "Movie_Title")

# %%
df.rename(columns={"Title": "Movie_Title"}, inplace=True)
df
# Out:
#      Rank              Movie_Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# 6) Get unique genres

# %%
unique_genres = df["Genre"].str.split(",").explode().unique()
print(unique_genres)
# Out:
# ['Action' 'Adventure' 'Sci-Fi' 'Mystery' 'Horror' 'Thriller' 'Animation'
#  'Comedy' 'Family' 'Fantasy' 'Drama' 'Music' 'Biography' 'Romance'
#  'History' 'Crime' 'Western' 'War' 'Musical' 'Sport']

# %% [markdown]
# 7) Extract number of genres per movie

# %%
df["Num_Genres"] = df["Genre"].str.count(",") + 1
print(df[["Genre", "Num_Genres"]])
# Out:
#                         Genre  Num_Genres
# 0     Action,Adventure,Sci-Fi           3
# 1    Adventure,Mystery,Sci-Fi           3
# 2             Horror,Thriller           2
# 3     Animation,Comedy,Family           3
# 4    Action,Adventure,Fantasy           3
# ..                        ...         ...
# 995       Crime,Drama,Mystery           3
# 996                    Horror           1
# 997       Drama,Music,Romance           3
# 998          Adventure,Comedy           2
# 999     Comedy,Family,Fantasy           3
#
# [1000 rows x 2 columns]

# %% [markdown]
# 8) Handle missing values in 'Revenue (Millions)' and 'Metascore

# %%
df[["Revenue (Millions)", "Metascore"]].isnull().sum()
# Out:
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %% [markdown]
# 9) Top 5 movies by Rating

# %%
top5_movie_rating = df.sort_values(by="Rating", ascending=False).head(5)
print(top5_movie_rating[["Movie_Title", "Rating",]])
# Out:
#           Movie_Title  Rating
# 54    The Dark Knight     9.0
# 80          Inception     8.8
# 117            Dangal     8.8
# 36       Interstellar     8.6
# 249  The Intouchables     8.6

# %% [markdown]
# 10) Movies with highest/lowest revenue

# %%
#highest income
highest_rev = df.loc[df["Revenue (Millions)"].idxmax()]
print("Highest Revenue Movie:")
print(highest_rev[["Movie_Title", "Revenue (Millions)"]])
# Out:
# Highest Revenue Movie:
# Movie_Title           Star Wars: Episode VII - The Force Awakens
# Revenue (Millions)                                        936.63
# Name: 50, dtype: object

# %%
#Lowest income
lowest_rev = df.loc[df["Revenue (Millions)"].idxmin()]
print("Lowest Revenue Movie:")
print(lowest_rev[["Movie_Title", "Revenue (Millions)"]])
# Out:
# Lowest Revenue Movie:
# Movie_Title           A Kind of Murder
# Revenue (Millions)                 0.0
# Name: 231, dtype: object

# %% [markdown]
# 11) Avg. rating by Director

# %%
avg_rating_director = df.groupby("Director")["Rating"].mean().sort_values(ascending=False)
avg_rating_director
# Out:
# Director
# Nitesh Tiwari                       8.80
# Christopher Nolan                   8.68
# Olivier Nakache                     8.60
# Makoto Shinkai                      8.60
# Florian Henckel von Donnersmarck    8.50
#                                     ...
# Micheal Bafaro                      3.50
# Jonathan Holbrook                   3.20
# Shawn Burkett                       2.70
# James Wong                          2.70
# Jason Friedberg                     1.90
# Name: Rating, Length: 644, dtype: float64

# %% [markdown]
# 12) Movies per year

# %%
movies_per_year = df.groupby("Year")["Movie_Title"].count()
movies_per_year
# Out:
# Year
# 2006     44
# 2007     53
# 2008     52
# 2009     51
# 2010     60
# 2011     63
# 2012     64
# 2013     91
# 2014     98
# 2015    127
# 2016    297
# Name: Movie_Title, dtype: int64

# %% [markdown]
# 13) Movies with rating > 8 & revenue > 100M

# %%
high_quality_movies = df[(df["Rating"] > 8) & (df["Revenue (Millions)"] > 100)]
high_quality_movies[["Movie_Title", "Rating", "Revenue (Millions)"]]
# Out:
#                                       Movie_Title  Rating  Revenue (Millions)
# 0                         Guardians of the Galaxy     8.1              333.13
# 6                                      La La Land     8.3              151.06
# 36                                   Interstellar     8.6              187.99
# 50     Star Wars: Episode VII - The Force Awakens     8.1              936.63
# 54                                The Dark Knight     9.0              533.32
# 67                             Mad Max: Fury Road     8.1              153.63
# 74                                       Zootopia     8.1              341.26
# 76                                   The Avengers     8.1              623.28
# 77                           Inglourious Basterds     8.3              120.52
# 80                                      Inception     8.8              292.57
# 82                        The Wolf of Wall Street     8.2              116.87
# ...

# %% [markdown]
# 14) Group by Director: avg Rating, Revenue

# %%
director_stats = df.groupby("Director")[["Rating","Revenue (Millions)"]].mean()
director_stats
# Out:
#                      Rating  Revenue (Millions)
# Director
# Aamir Khan             8.50               1.200
# Abdellatif Kechiche    7.80               2.200
# Adam Leon              6.50                 NaN
# Adam McKay             7.00             109.535
# Adam Shankman          6.30              78.665
# ...                     ...                 ...
# Xavier Dolan           7.55               3.490
# Yimou Zhang            6.10              45.130
# Yorgos Lanthimos       7.20               4.405
# Zack Snyder            7.04             195.148
# Zackary Adler          5.10               6.530
#
# [644 rows x 2 columns]

# %% [markdown]
# 15) Group by Year: count, avg Rating

# %%
df.groupby("Year").agg(Movie_Count=("Movie_Title","count"), Avg_Rating=("Rating","mean"))
# Out:
#       Movie_Count  Avg_Rating
# Year
# 2006           44    7.125000
# 2007           53    7.133962
# 2008           52    6.784615
# 2009           51    6.960784
# 2010           60    6.826667
# 2011           63    6.838095
# 2012           64    6.925000
# 2013           91    6.812088
# 2014           98    6.837755
# 2015          127    6.602362
# 2016          297    6.436700

# %% [markdown]
# 16) Create a new column Profitability.\
# a) Revenue divided by Duration\
# b) Find top 10 most profitable movies

# %%
df["Profitability"] = df["Revenue (Millions)"] / df["Runtime (Minutes)"]
df
# Out:
#      Rank              Movie_Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
# Find top 10 most profitable movies
top10_profitable_movies = df.sort_values(by="Profitability", ascending=False).head(10)
top10_profitable_movies[["Movie_Title", "Profitability"]]
# Out:
#                                     Movie_Title  Profitability
# 50   Star Wars: Episode VII - The Force Awakens       6.886985
# 85                               Jurassic World       5.259516
# 119                                Finding Dory       5.013299
# 87                                       Avatar       4.694506
# 76                                 The Avengers       4.358601
# 15                      The Secret Life of Pets       4.233448
# 688                                 Toy Story 3       4.028932
# 12                                    Rogue One       4.001278
# 174                                      Frozen       3.928824
# 797                             Despicable Me 2       3.755612

# %% [markdown]
# 17) Create a column that categorizes movies by rating:\
# a) Rating < 6: Poor\
# b) 6 ≤ Rating < 7.5: Average\
# c) Rating ≥ 7.5: Excellent

# %%
def categorize_rating(r):
  if r < 6:
    return "Poor"
  elif r < 7.5:
    return "Average"
  else:
    return "Excellent"

df["Rating_Category"] = df["Rating"].apply(categorize_rating)

print(df[["Movie_Title", "Rating", "Rating_Category"]].head(7))
# Out:
#                Movie_Title  Rating Rating_Category
# 0  Guardians of the Galaxy     8.1       Excellent
# 1               Prometheus     7.0         Average
# 2                    Split     7.3         Average
# 3                     Sing     7.2         Average
# 4            Suicide Squad     6.2         Average
# 5           The Great Wall     6.1         Average
# 6               La La Land     8.3       Excellent

# %% [markdown]
# 18) Create a custom function to score movies based on:\
# i) Apply row['Rating'] * 10 + row['Revenue (Millions)'] as High score\
# ii)Apply a function to dataset to assign the score

# %%
def score_movie(row):
  return row["Rating"] * 10 + row["Revenue (Millions)"]

df["High_Score"] = df.apply(score_movie, axis=1)

print(df[["Movie_Title", "Rating", "Revenue (Millions)", "High_Score"]].head())
# Out:
#                Movie_Title  Rating  Revenue (Millions)  High_Score
# 0  Guardians of the Galaxy     8.1              333.13      414.13
# 1               Prometheus     7.0              126.46      196.46
# 2                    Split     7.3              138.12      211.12
# 3                     Sing     7.2              270.32      342.32
# 4            Suicide Squad     6.2              325.02      387.02
